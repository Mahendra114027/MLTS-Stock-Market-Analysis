# %% [markdown]
# # Exploratory Data Analysis of Stock Market Data

# %% [markdown]
# ## Imports

# %%
# !pip install statsmodels plotly pandas tabulate
# Out:
# Requirement already satisfied: statsmodels in /home/mahi/anaconda3/lib/python3.9/site-packages (0.12.2)
# Requirement already satisfied: plotly in /home/mahi/anaconda3/lib/python3.9/site-packages (5.13.0)
# Requirement already satisfied: pandas in /home/mahi/anaconda3/lib/python3.9/site-packages (1.3.4)
# Requirement already satisfied: tabulate in /home/mahi/anaconda3/lib/python3.9/site-packages (0.9.0)
# Requirement already satisfied: patsy>=0.5 in /home/mahi/anaconda3/lib/python3.9/site-packages (from statsmodels) (0.5.2)
# Requirement already satisfied: numpy>=1.15 in /home/mahi/anaconda3/lib/python3.9/site-packages (from statsmodels) (1.20.3)
# Requirement already satisfied: scipy>=1.1 in /home/mahi/anaconda3/lib/python3.9/site-packages (from statsmodels) (1.7.1)
# Requirement already satisfied: tenacity>=6.2.0 in /home/mahi/anaconda3/lib/python3.9/site-packages (from plotly) (8.1.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/mahi/anaconda3/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /home/mahi/anaconda3/lib/python3.9/site-packages (from pandas) (2021.3)
# Requirement already satisfied: six in /home/mahi/anaconda3/lib/python3.9/site-packages (from patsy>=0.5->statsmodels) (1.16.0)

# %%
from plotly.offline import plot, iplot, init_notebook_mode
from statsmodels.tsa.seasonal import seasonal_decompose
from plotly.subplots import make_subplots
import matplotlib.pyplot as plt
import plotly.graph_objs as go
from tabulate import tabulate
import seaborn as sns
import pandas as pd
import tabulate
import warnings

# %% [markdown]
# ## Options

# %%
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %% [markdown]
# ## Functions

# %%
def split_date(df, target_col, new_alias=None):
    """
    Utility to convert a date column into various date entities like year, month, day, etc.

    Args:
        df (pd.DataFrame): Input DataFrame
        target_col (string): Feature on which the split needs to be performed. Must be of datetime type
        new_alias (string): String alias to be used for split columns generated from target_col.
                            In case no value is passed then it is same as target_col
    """
    
    if new_alias is None:
        new_alias = target_col
    
    df[f'{new_alias}_year'] = df[target_col].dt.year
    df[f'{new_alias}_month'] = df[target_col].dt.month
    df[f'{new_alias}_day'] = df[target_col].dt.day
    df[f'{new_alias}_quarter'] = df[target_col].dt.quarter
    df[f'{new_alias}_is_month_start'] = df[target_col].dt.is_month_start.astype(int)
    df[f'{new_alias}_is_month_end'] = df[target_col].dt.is_month_end.astype(int)
    
    return df

# %% [markdown]
# ## Load Data

# %% [markdown]
# ### Original raw data

# %%
raw_aapl_df = pd.read_csv('../static/datasets/original/aapl.csv', parse_dates=['Date'])
raw_aapl_df.columns = raw_aapl_df.columns.str.lower().str.replace(' ', '_')

raw_gmbl_df = pd.read_csv('../static/datasets/original/gmbl.csv', parse_dates=['Date'])
raw_gmbl_df.columns = raw_gmbl_df.columns.str.lower().str.replace(' ', '_')

raw_tsla_df = pd.read_csv('../static/datasets/original/tsla.csv', parse_dates=['Date'])
raw_tsla_df.columns = raw_tsla_df.columns.str.lower().str.replace(' ', '_')

# %% [markdown]
# #### Shape and Size

# %%
table = [
    ['Raw Stock Data','Shape','Size'],
    ['Apple', raw_aapl_df.shape, raw_aapl_df.size],
    ['Tesla', raw_tsla_df.shape, raw_tsla_df.size],
    ['Esports Entertainment Group', raw_gmbl_df.shape, raw_gmbl_df.size]
]

print(tabulate.tabulate(table, headers='firstrow', tablefmt='grid'))
# Out:
# +-----------------------------+------------+--------+
# | Raw Stock Data              | Shape      |   Size |
# +=============================+============+========+
# | Apple                       | (10623, 7) |  74361 |
# +-----------------------------+------------+--------+
# | Tesla                       | (3170, 7)  |  22190 |
# +-----------------------------+------------+--------+
# | Esports Entertainment Group | (1393, 7)  |   9751 |
# +-----------------------------+------------+--------+

# %% [markdown]
# ### Preprocessed Data

# %%
aapl_df = pd.read_csv('../static/datasets/preprocessed_aapl.csv', parse_dates=['date'])
gmbl_df = pd.read_csv('../static/datasets/preprocessed_gmbl.csv', parse_dates=['date'])
tsla_df = pd.read_csv('../static/datasets/preprocessed_tsla.csv', parse_dates=['date'])

# %% [markdown]
# #### Shape and Size

# %%
table = [
    ['Preprocessed Stock Data','Shape','Size'],
    ['Apple', aapl_df.shape, aapl_df.size],
    ['Tesla', tsla_df.shape, tsla_df.size],
    ['Esports Entertainment Group', gmbl_df.shape, gmbl_df.size]
]

print(tabulate.tabulate(table, headers='firstrow', tablefmt='grid'))
# Out:
# +-----------------------------+-------------+--------+
# | Preprocessed Stock Data     | Shape       |   Size |
# +=============================+=============+========+
# | Apple                       | (10620, 33) | 350460 |
# +-----------------------------+-------------+--------+
# | Tesla                       | (3167, 33)  | 104511 |
# +-----------------------------+-------------+--------+
# | Esports Entertainment Group | (1390, 33)  |  45870 |
# +-----------------------------+-------------+--------+

# %% [markdown]
# ### Apple Stocks

# %%
aapl_df.head()
# Out:
#         date  date_year  date_month  date_day  date_quarter  \
# 0 1980-12-17       1980          12        17             4
# 1 1980-12-18       1980          12        18             4
# 2 1980-12-19       1980          12        19             4
# 3 1980-12-22       1980          12        22             4
# 4 1980-12-23       1980          12        23             4
#
#    date_is_month_start  date_is_month_end  returns_prc  day_num  \
# 0                    0                  0          0.0        3
# 1                    0                  0          0.0        4
# 2                    0                  0          0.0        5
# 3                    0                  0          0.0        6
# 4                    0                  0          0.0        7
#
#    high_low_diff_mean  ...  lag_2_open_close_diff  lag_3_open_close_diff  \
# 0               0.001  ...                  0.558                  0.000
# 1               0.001  ...                  0.558                  0.558
# 2               0.001  ...                  0.000                  0.558
# 3               0.001  ...                  0.000                  0.000
# 4               0.001  ...                  0.000                  0.000
#
#    volume  lag_1_volume  lag_2_volume  lag_3_volume  adj_close  \
# 0   0.000  1.928640e+10  8.944320e+10  3.825920e+11      0.000
# 1  -0.707  7.070000e-01  2.806000e+00  1.044300e+01      0.707
# 2  -1.087  2.050000e-01  8.810000e-01  1.885000e+00      1.098
# 3  -0.855 -2.450000e-01  1.100000e+00  1.803000e+00      0.971
# 4   0.434 -1.144000e+00  7.100000e-01  4.793000e+00      0.984
#
#    lag_1_adj_close  lag_2_adj_close  lag_3_adj_close
# 0           -2.171            4.777            9.988
# 1           -0.707           -1.885            1.885
# 2           -0.240           -0.858           -1.373
# 3            0.056           -1.027           -1.526
# 4            0.032           -1.015           -2.253
#
# [5 rows x 33 columns]

# %% [markdown]
# ### Tesla Stocks

# %%
tsla_df.head()
# Out:
#         date  date_year  date_month  date_day  date_quarter  \
# 0 2010-07-02       2010           7         2             3
# 1 2010-07-06       2010           7         6             3
# 2 2010-07-07       2010           7         7             3
# 3 2010-07-08       2010           7         8             3
# 4 2010-07-09       2010           7         9             3
#
#    date_is_month_start  date_is_month_end  returns_prc  day_num  \
# 0                    0                  0      -19.792        3
# 1                    0                  0      -24.146        4
# 2                    0                  0       -3.797        5
# 3                    0                  0        7.560        6
# 4                    0                  0       -1.034        7
#
#    high_low_diff_mean  ...  lag_2_open_close_diff  lag_3_open_close_diff  \
# 0               0.293  ...               -122.667               -579.333
# 1               0.285  ...                -12.649                -29.620
# 2               0.227  ...                  0.553                  0.148
# 3               0.173  ...                  1.075                  1.041
# 4               0.110  ...                  0.773                  4.032
#
#    volume  lag_1_volume  lag_2_volume  lag_3_volume  adj_close  \
# 0   0.000  4.618500e+10  1.807095e+11  2.043975e+11      0.000
# 1   0.707 -7.070000e-01  1.814000e+00  9.158000e+00     -0.707
# 2   0.604  5.500000e-01 -1.154000e+00  1.884000e+00     -0.658
# 3   1.153 -5.180000e-01 -6.340000e-01 -4.289000e+00      1.137
# 4  -1.130  7.700000e-01  3.600000e-01  3.320000e-01      0.545
#
#    lag_1_adj_close  lag_2_adj_close  lag_3_adj_close
# 0          184.000          308.667          312.667
# 1            0.707            1.970            2.826
# 2           -0.493            1.151            2.619
# 3           -0.744           -0.393            3.108
# 4            0.609           -1.154           -0.825
#
# [5 rows x 33 columns]

# %% [markdown]
# ### Esports Entertainment Group

# %%
gmbl_df.head()
# Out:
#         date  date_year  date_month  date_day  date_quarter  \
# 0 2017-07-25       2017           7        25             3
# 1 2017-07-26       2017           7        26             3
# 2 2017-07-27       2017           7        27             3
# 3 2017-07-28       2017           7        28             3
# 4 2017-07-31       2017           7        31             3
#
#    date_is_month_start  date_is_month_end  returns_prc  day_num  \
# 0                    0                  0       -1.014        3
# 1                    0                  0       -0.339        4
# 2                    0                  0        0.000        5
# 3                    0                  0       -0.678        6
# 4                    0                  1      -16.390        7
#
#    high_low_diff_mean  ...  lag_2_open_close_diff  lag_3_open_close_diff  \
# 0               1.200  ...               9600.003               -449.996
# 1               1.800  ...                -16.264                 45.963
# 2               1.650  ...                  1.091                -14.621
# 3               1.525  ...                  0.000                  2.000
# 4               3.695  ...                 -0.620                 -0.577
#
#    volume  lag_1_volume  lag_2_volume  lag_3_volume  adj_close  \
# 0   0.000    106000.000    726000.000    393000.000      0.000
# 1  -0.707         0.707         1.569         6.608     -0.707
# 2  -0.899        -0.178         1.077         1.841      0.577
# 3   0.990        -1.010         0.021         1.814     -0.577
# 4   1.063        -0.142        -0.921        -0.520     -1.154
#
#    lag_1_adj_close  lag_2_adj_close  lag_3_adj_close
# 0         -750.000        -9450.001          599.998
# 1            0.707           -6.364          -88.387
# 2           -1.155            0.577           -8.083
# 3            1.155           -0.577            1.155
# 4            0.557            0.597            0.557
#
# [5 rows x 33 columns]

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Dataframe

# %% [markdown]
# So basically this dataset contains 6 different features i.e. date, open, high, low, close, volume
# - Date - This contains date + time at the instant of trade
# - Open - Open is the price when the stock began
# - High - Maximum price at the given time period
# - Low - Minimum price at the given time period
# - Close - Price at which stock ended
# - Adj Close - Adjusted closing price
# - Volume - It is the total amount of trading activity

# %%
raw_aapl_df.head()
# Out:
#         date      open      high       low     close  adj_close     volume
# 0 1980-12-12  0.128348  0.128906  0.128348  0.128348   0.099874  469033600
# 1 1980-12-15  0.122210  0.122210  0.121652  0.121652   0.094663  175884800
# 2 1980-12-16  0.113281  0.113281  0.112723  0.112723   0.087715  105728000
# 3 1980-12-17  0.115513  0.116071  0.115513  0.115513   0.089886   86441600
# 4 1980-12-18  0.118862  0.119420  0.118862  0.118862   0.092492   73449600

# %% [markdown]
# ### Column datatypes

# %%
raw_aapl_df.dtypes
# Out:
# date         datetime64[ns]
# open                float64
# high                float64
# low                 float64
# close               float64
# adj_close           float64
# volume                int64
# dtype: object

# %% [markdown]
# ### Info and Description

# %% [markdown]
# #### Apple

# %%
raw_aapl_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10623 entries, 0 to 10622
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       10623 non-null  datetime64[ns]
#  1   open       10623 non-null  float64
#  2   high       10623 non-null  float64
#  3   low        10623 non-null  float64
#  4   close      10623 non-null  float64
#  5   adj_close  10623 non-null  float64
#  6   volume     10623 non-null  int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 581.1 KB

# %%
raw_aapl_df.describe()
# Out:
#                open          high           low         close     adj_close  \
# count  10623.000000  10623.000000  10623.000000  10623.000000  10623.000000
# mean      16.692852     16.883576     16.504529     16.700995     16.031888
# std       35.473142     35.905316     35.053934     35.496359     35.178076
# min        0.049665      0.049665      0.049107      0.049107      0.038213
# 25%        0.287901      0.294643      0.281250      0.287946      0.238015
# 50%        0.487165      0.495536      0.479286      0.486607      0.404058
# 75%       16.309464     16.414108     16.111250     16.257858     14.054503
# max      182.630005    182.940002    179.119995    182.009995    180.959732
#
#              volume
# count  1.062300e+04
# mean   3.271862e+08
# std    3.377143e+08
# min    0.000000e+00
# 25%    1.210850e+08
# 50%    2.143456e+08
# 75%    4.065544e+08
# max    7.421641e+09

# %% [markdown]
# #### Tesla

# %%
raw_tsla_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3170 entries, 0 to 3169
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       3170 non-null   datetime64[ns]
#  1   open       3170 non-null   float64
#  2   high       3170 non-null   float64
#  3   low        3170 non-null   float64
#  4   close      3170 non-null   float64
#  5   adj_close  3170 non-null   float64
#  6   volume     3170 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 173.5 KB

# %%
raw_tsla_df.describe()
# Out:
#               open         high          low        close    adj_close  \
# count  3170.000000  3170.000000  3170.000000  3170.000000  3170.000000
# mean     59.324018    60.662926    57.851085    59.283133    59.283133
# std      95.546640    97.750441    93.063735    95.425467    95.425467
# min       1.076000     1.108667     0.998667     1.053333     1.053333
# 25%       9.104834     9.391666     8.915667     9.176666     9.176666
# 50%      16.327666    16.529000    16.063999    16.315666    16.315666
# 75%      25.106834    25.557832    24.667165    25.173501    25.173501
# max     411.470001   414.496674   405.666656   409.970001   409.970001
#
#              volume
# count  3.170000e+03
# mean   9.423474e+07
# std    8.188300e+07
# min    1.777500e+06
# 25%    4.256085e+07
# 50%    7.616385e+07
# 75%    1.187124e+08
# max    9.140820e+08

# %% [markdown]
# #### Esports Gaming Group

# %%
raw_gmbl_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1393 entries, 0 to 1392
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       1393 non-null   datetime64[ns]
#  1   open       1393 non-null   float64
#  2   high       1393 non-null   float64
#  3   low        1393 non-null   float64
#  4   close      1393 non-null   float64
#  5   adj_close  1393 non-null   float64
#  6   volume     1393 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 76.3 KB

# %%
raw_gmbl_df.describe()
# Out:
#               open         high          low        close    adj_close  \
# count  1393.000000  1393.000000  1393.000000  1393.000000  1393.000000
# mean      8.630961     9.032708     8.107154     8.577028     8.577028
# std       8.137858     8.331656     7.730892     8.020879     8.020879
# min       0.072000     0.073000     0.067000     0.071000     0.071000
# 25%       4.200000     4.395000     3.945000     4.180000     4.180000
# 50%       7.200000     7.500000     6.531000     7.200000     7.200000
# 75%      10.800000    11.250000    10.200000    10.570000    10.570000
# max      45.000000    47.099998    45.000000    45.000000    45.000000
#
#              volume
# count  1.393000e+03
# mean   1.277801e+06
# std    1.149076e+07
# min    0.000000e+00
# 25%    4.400000e+02
# 50%    9.740000e+04
# 75%    5.343000e+05
# max    3.153843e+08

# %% [markdown]
# ### Missing Values

# %%
null_values_df = raw_aapl_df.isnull().sum().reset_index()
null_values_df.columns = ['feature', 'apple']
null_values_df['tesla'] = raw_tsla_df.isnull().sum().reset_index(drop=True)
null_values_df['gmbl'] = raw_gmbl_df.isnull().sum().reset_index(drop=True)

print(
    tabulate.tabulate(
        null_values_df,
        tablefmt='grid',
        headers=['Feature', 'Apple', 'Tesla', 'Esports Gaming Group']
    )
)
# Out:
# +----+-----------+---------+---------+------------------------+
# |    | Feature   |   Apple |   Tesla |   Esports Gaming Group |
# +====+===========+=========+=========+========================+
# |  0 | date      |       0 |       0 |                      0 |
# +----+-----------+---------+---------+------------------------+
# |  1 | open      |       0 |       0 |                      0 |
# +----+-----------+---------+---------+------------------------+
# |  2 | high      |       0 |       0 |                      0 |
# +----+-----------+---------+---------+------------------------+
# |  3 | low       |       0 |       0 |                      0 |
# +----+-----------+---------+---------+------------------------+
# |  4 | close     |       0 |       0 |                      0 |
# +----+-----------+---------+---------+------------------------+
# |  5 | adj_close |       0 |       0 |                      0 |
# +----+-----------+---------+---------+------------------------+
# |  6 | volume    |       0 |       0 |                      0 |
# +----+-----------+---------+---------+------------------------+

# %% [markdown]
# ### Columns skew

# %% [markdown]
# #### Apple

# %%
table = pd.DataFrame()
table = raw_aapl_df.skew(numeric_only=True).reset_index()
table.columns = ['feature', 'skew_values']
display(table)

sns.displot(data=table, x='skew_values', y='feature');
# Out:
#      feature  skew_values
# 0       open     2.872413
# 1       high     2.875039
# 2        low     2.869537
# 3      close     2.872356
# 4  adj_close     2.937300
# 5     volume     3.551962

# %% [markdown]
# #### Tesla

# %%
table = pd.DataFrame()
table = raw_tsla_df.skew(numeric_only=True).reset_index()
table.columns = ['feature', 'skew_values']
display(table)

sns.displot(data=table, x='skew_values', y='feature');
# Out:
#      feature  skew_values
# 0       open     1.821943
# 1       high     1.820862
# 2        low     1.821147
# 3      close     1.820062
# 4  adj_close     1.820062
# 5     volume     2.343361

# %% [markdown]
# #### Esports Gaming Group

# %%
table = pd.DataFrame()
table = raw_gmbl_df.skew(numeric_only=True).reset_index()
table.columns = ['feature', 'skew_values']
display(table)

sns.displot(data=table, x='skew_values', y='feature');
# Out:
#      feature  skew_values
# 0       open     2.228769
# 1       high     2.126755
# 2        low     2.286895
# 3      close     2.211915
# 4  adj_close     2.211915
# 5     volume    22.616633

# %% [markdown]
# ### Correaltion

# %% [markdown]
# #### Apple

# %%
correlations = raw_aapl_df.corr()
correlations
# Out:
#                open      high       low     close  adj_close    volume
# open       1.000000  0.999939  0.999923  0.999839   0.999551 -0.214530
# high       0.999939  1.000000  0.999911  0.999924   0.999663 -0.214008
# low        0.999923  0.999911  1.000000  0.999927   0.999620 -0.215379
# close      0.999839  0.999924  0.999927  1.000000   0.999718 -0.214706
# adj_close  0.999551  0.999663  0.999620  0.999718   1.000000 -0.217177
# volume    -0.214530 -0.214008 -0.215379 -0.214706  -0.217177  1.000000

# %%
plt.figure(figsize=(12, 8))
heatmap = sns.heatmap(correlations.round(2), vmin=-1, vmax=1, annot=True, cmap='crest')
heatmap.set_title('Feature Correlations - Apple Dataset');

# %%
correlations = aapl_df.corr()
correlations
# Out:
#                        date_year  date_month  date_day  date_quarter  \
# date_year               1.000000   -0.005814 -0.001605     -0.004962
# date_month             -0.005814    1.000000  0.000419      0.971159
# date_day               -0.001605    0.000419  1.000000      0.005259
# date_quarter           -0.004962    0.971159  0.005259      1.000000
# date_is_month_start     0.002583    0.023408 -0.298540      0.019627
# date_is_month_end       0.000877    0.001788  0.312204      0.001230
# returns_prc             0.030765   -0.014204 -0.017079     -0.011276
# day_num                 0.999716    0.017899  0.000382      0.018080
# high_low_diff_mean      0.568449    0.013311 -0.004747      0.010431
# high_low_diff_std       0.496468    0.027643 -0.002837      0.026756
# open_close_diff_mean   -0.039144    0.005350 -0.002179     -0.000979
# open_close_diff_std     0.509689    0.018810  0.001374      0.017208
# volume_mean             0.158367   -0.057987 -0.006443     -0.042255
# volume_std             -0.002679   -0.036445  0.003605     -0.016922
# adj_close_mean          0.642979    0.022240  0.000965      0.022632
# adj_close_std           0.493012    0.006976 -0.002954      0.004833
# high_low_diff          -0.005884   -0.001675 -0.004997      0.001899
# lag_1_high_low_diff    -0.003942   -0.000698  0.001809     -0.001908
# lag_2_high_low_diff     0.009631    0.002349  0.003255     -0.000053
# lag_3_high_low_diff     0.032677    0.007151  0.002220      0.006269
# open_close_diff         0.002083   -0.002152  0.004953     -0.002859
# lag_1_open_close_diff   0.001890   -0.000757 -0.005241     -0.000450
# lag_2_open_close_diff  -0.004300    0.003204  0.000283      0.003554
# lag_3_open_close_diff   0.003996   -0.000355  0.004306     -0.000766
# volume                 -0.012724   -0.011442  0.007307     -0.006835
# lag_1_volume           -0.017154    0.015428  0.001392      0.012940
# lag_2_volume           -0.017154    0.015428  0.001392      0.012940
# lag_3_volume           -0.017154    0.015428  0.001392      0.012940
# adj_close               0.044356   -0.000534 -0.021073      0.008807
# lag_1_adj_close        -0.000851    0.000982  0.007489      0.000754
# lag_2_adj_close        -0.043421   -0.000119  0.014982     -0.009215
# lag_3_adj_close        -0.049043   -0.002547  0.008919     -0.010697
#
#                        date_is_month_start  date_is_month_end  returns_prc  \
# date_year                         0.002583           0.000877     0.030765
# date_month                        0.023408           0.001788    -0.014204
# date_day                         -0.298540           0.312204    -0.017079
# date_quarter                      0.019627           0.001230    -0.011276
# date_is_month_start               1.000000          -0.032937     0.027178
# date_is_month_end                -0.032937           1.000000     0.002781
# returns_prc                       0.027178           0.002781     1.000000
# day_num                           0.002543           0.001537     0.030381
# high_low_diff_mean                0.004810           0.004118     0.008150
# high_low_diff_std                 0.011717           0.016252     0.001686
# open_close_diff_mean             -0.014113          -0.007319    -0.156219
# open_close_diff_std               0.002171           0.007374     0.007944
# volume_mean                      -0.009864          -0.009638    -0.027670
# volume_std                       -0.008018          -0.002471    -0.048166
# adj_close_mean                    0.003843           0.001462     0.018706
# adj_close_std                     0.004554           0.012870     0.009823
# high_low_diff                     0.010757          -0.009844     0.005635
# lag_1_high_low_diff              -0.009489           0.007101     0.003103
# lag_2_high_low_diff              -0.001612           0.003002    -0.008599
# lag_3_high_low_diff               0.012249          -0.011770    -0.000789
# open_close_diff                  -0.006413           0.004744    -0.659890
# lag_1_open_close_diff             0.006923          -0.007106     0.327197
# lag_2_open_close_diff            -0.000489           0.002256     0.334195
# lag_3_open_close_diff             0.003430          -0.002137     0.173030
# volume                           -0.017634           0.021996     0.035786
# lag_1_volume                     -0.001719          -0.001805     0.000250
# lag_2_volume                     -0.001719          -0.001805     0.000250
# lag_3_volume                     -0.001719          -0.001805     0.000250
# adj_close                         0.016190          -0.004208     0.636774
# lag_1_adj_close                  -0.006758           0.001878    -0.493471
# lag_2_adj_close                  -0.010738           0.002677    -0.243119
# lag_3_adj_close                  -0.012456          -0.004401    -0.064431
#
#                         day_num  high_low_diff_mean  high_low_diff_std  ...  \
# date_year              0.999716            0.568449           0.496468  ...
# date_month             0.017899            0.013311           0.027643  ...
# date_day               0.000382           -0.004747          -0.002837  ...
# date_quarter           0.018080            0.010431           0.026756  ...
# date_is_month_start    0.002543            0.004810           0.011717  ...
# date_is_month_end      0.001537            0.004118           0.016252  ...
# returns_prc            0.030381            0.008150           0.001686  ...
# day_num                1.000000            0.568316           0.496735  ...
# high_low_diff_mean     0.568316            1.000000           0.883990  ...
# high_low_diff_std      0.496735            0.883990           1.000000  ...
# open_close_diff_mean  -0.038978            0.007607           0.000021  ...
# open_close_diff_std    0.509743            0.918144           0.853332  ...
# volume_mean            0.157343           -0.168082          -0.139370  ...
# volume_std            -0.003223           -0.143745          -0.105270  ...
# adj_close_mean         0.643005            0.916551           0.787162  ...
# adj_close_std          0.492786            0.879065           0.780466  ...
# high_low_diff         -0.005948           -0.002729           0.011915  ...
# lag_1_high_low_diff   -0.003948            0.003763           0.001714  ...
# lag_2_high_low_diff    0.009701           -0.000907          -0.013543  ...
# lag_3_high_low_diff    0.032869           -0.034138          -0.048229  ...
# open_close_diff        0.002041           -0.001424           0.006912  ...
# lag_1_open_close_diff  0.001860           -0.000001          -0.002871  ...
# lag_2_open_close_diff -0.004221            0.001335          -0.004127  ...
# lag_3_open_close_diff  0.003986            0.008565           0.004552  ...
# volume                -0.012993           -0.005633           0.010472  ...
# lag_1_volume          -0.016807           -0.003942          -0.003484  ...
# lag_2_volume          -0.016807           -0.003942          -0.003484  ...
# lag_3_volume          -0.016807           -0.003942          -0.003484  ...
# adj_close              0.044271           -0.004326          -0.003281  ...
# lag_1_adj_close       -0.000810           -0.003313           0.005344  ...
# lag_2_adj_close       -0.043366            0.006854          -0.000979  ...
# lag_3_adj_close       -0.049062            0.006216          -0.008048  ...
#
#                        lag_2_open_close_diff  lag_3_open_close_diff    volume  \
# date_year                          -0.004300               0.003996 -0.012724
# date_month                          0.003204              -0.000355 -0.011442
# date_day                            0.000283               0.004306  0.007307
# date_quarter                        0.003554              -0.000766 -0.006835
# date_is_month_start                -0.000489               0.003430 -0.017634
# date_is_month_end                   0.002256              -0.002137  0.021996
# returns_prc                         0.334195               0.173030  0.035786
# day_num                            -0.004221               0.003986 -0.012993
# high_low_diff_mean                  0.001335               0.008565 -0.005633
# high_low_diff_std                  -0.004127               0.004552  0.010472
# open_close_diff_mean                0.005692              -0.128300  0.043493
# open_close_diff_std                 0.000256               0.001230 -0.005332
# volume_mean                        -0.004506              -0.013617 -0.018350
# volume_std                         -0.007996              -0.048449  0.027953
# adj_close_mean                     -0.005948               0.003233 -0.008609
# adj_close_std                       0.014456               0.015424  0.051470
# high_low_diff                       0.000618               0.002216  0.481911
# lag_1_high_low_diff                 0.008294              -0.010340 -0.140178
# lag_2_high_low_diff                -0.008589               0.007737 -0.345989
# lag_3_high_low_diff                -0.017489              -0.040440 -0.091901
# open_close_diff                    -0.510266               0.007783 -0.057646
# lag_1_open_close_diff              -0.497588              -0.002263  0.026790
# lag_2_open_close_diff               1.000000              -0.005518  0.030909
# lag_3_open_close_diff              -0.005518               1.000000  0.008258
# volume                              0.030909               0.008258  1.000000
# lag_1_volume                        0.006796               0.000030  0.000410
# lag_2_volume                        0.006796               0.000030  0.000410
# lag_3_volume                        0.006796               0.000030  0.000410
# adj_close                           0.409149               0.217379  0.008137
# lag_1_adj_close                    -0.016132               0.006648 -0.050411
# lag_2_adj_close                    -0.392616              -0.220614  0.031717
# lag_3_adj_close                     0.352122              -0.148941  0.052972
#
#                        lag_1_volume  lag_2_volume  lag_3_volume  adj_close  \
# date_year                 -0.017154     -0.017154     -0.017154   0.044356
# date_month                 0.015428      0.015428      0.015428  -0.000534
# date_day                   0.001392      0.001392      0.001392  -0.021073
# date_quarter               0.012940      0.012940      0.012940   0.008807
# date_is_month_start       -0.001719     -0.001719     -0.001719   0.016190
# date_is_month_end         -0.001805     -0.001805     -0.001805  -0.004208
# returns_prc                0.000250      0.000250      0.000250   0.636774
# day_num                   -0.016807     -0.016807     -0.016807   0.044271
# high_low_diff_mean        -0.003942     -0.003942     -0.003942  -0.004326
# high_low_diff_std         -0.003484     -0.003484     -0.003484  -0.003281
# open_close_diff_mean       0.000223      0.000223      0.000223  -0.220453
# open_close_diff_std       -0.003538     -0.003538     -0.003538  -0.003117
# volume_mean               -0.007559     -0.007559     -0.007559   0.009016
# volume_std                -0.006422     -0.006422     -0.006422  -0.014247
# adj_close_mean            -0.004398     -0.004398     -0.004398   0.017530
# adj_close_std             -0.003374     -0.003374     -0.003374   0.010862
# high_low_diff              0.000300      0.000300      0.000300  -0.037941
# lag_1_high_low_diff        0.000044      0.000044      0.000044   0.018283
# lag_2_high_low_diff       -0.000342     -0.000342     -0.000342   0.020277
# lag_3_high_low_diff       -0.001283     -0.001283     -0.001283   0.027008
# open_close_diff           -0.000014     -0.000014     -0.000014  -0.467243
# lag_1_open_close_diff      0.006870      0.006870      0.006870   0.057066
# lag_2_open_close_diff      0.006796      0.006796      0.006796   0.409149
# lag_3_open_close_diff      0.000030      0.000030      0.000030   0.217379
# volume                     0.000410      0.000410      0.000410   0.008137
# lag_1_volume               1.000000      1.000000      1.000000  -0.000445
# lag_2_volume               1.000000      1.000000      1.000000  -0.000445
# lag_3_volume               1.000000      1.000000      1.000000  -0.000445
# adj_close                 -0.000445     -0.000445     -0.000445   1.000000
# lag_1_adj_close           -0.031162     -0.031162     -0.031162  -0.386448
# lag_2_adj_close            0.054262      0.054262      0.054262  -0.687241
# lag_3_adj_close            0.029208      0.029208      0.029208  -0.169130
#
#                        lag_1_adj_close  lag_2_adj_close  lag_3_adj_close
# date_year                    -0.000851        -0.043421        -0.049043
# date_month                    0.000982        -0.000119        -0.002547
# date_day                      0.007489         0.014982         0.008919
# date_quarter                  0.000754        -0.009215        -0.010697
# date_is_month_start          -0.006758        -0.010738        -0.012456
# date_is_month_end             0.001878         0.002677        -0.004401
# returns_prc                  -0.493471        -0.243119        -0.064431
# day_num                      -0.000810        -0.043366        -0.049062
# high_low_diff_mean           -0.003313         0.006854         0.006216
# high_low_diff_std             0.005344        -0.000979        -0.008048
# open_close_diff_mean          0.004432         0.214922         0.180019
# open_close_diff_std          -0.003881         0.006107         0.002277
# volume_mean                   0.003403        -0.011669        -0.005230
# volume_std                    0.011403         0.005091         0.005632
# adj_close_mean                0.000676        -0.017935        -0.024034
# adj_close_std                -0.002013        -0.009210         0.010533
# high_low_diff                 0.009305         0.030272         0.028147
# lag_1_high_low_diff          -0.035752         0.009990         0.020680
# lag_2_high_low_diff           0.025100        -0.039816        -0.047960
# lag_3_high_low_diff          -0.011819        -0.017480        -0.029606
# open_close_diff               0.671215        -0.064507        -0.237181
# lag_1_open_close_diff        -0.661115         0.463138        -0.116815
# lag_2_open_close_diff        -0.016132        -0.392616         0.352122
# lag_3_open_close_diff         0.006648        -0.220614        -0.148941
# volume                       -0.050411         0.031717         0.052972
# lag_1_volume                 -0.031162         0.054262         0.029208
# lag_2_volume                 -0.031162         0.054262         0.029208
# lag_3_volume                 -0.031162         0.054262         0.029208
# adj_close                    -0.386448        -0.687241        -0.169130
# lag_1_adj_close               1.000000        -0.403578        -0.104385
# lag_2_adj_close              -0.403578         1.000000         0.250306
# lag_3_adj_close              -0.104385         0.250306         1.000000
#
# [32 rows x 32 columns]

# %%
plt.figure(figsize=(12, 8))
heatmap = sns.heatmap(correlations.round(2), vmin=-1, vmax=1, cmap='RdYlBu')
heatmap.set_title('Feature Correlations - Preprocessed Apple Dataset');

# %% [markdown]
# #### Tesla

# %%
correlations = raw_tsla_df.corr()
correlations
# Out:
#                open      high       low     close  adj_close    volume
# open       1.000000  0.999725  0.999597  0.999191   0.999191  0.064499
# high       0.999725  1.000000  0.999608  0.999635   0.999635  0.068149
# low        0.999597  0.999608  1.000000  0.999675   0.999675  0.060838
# close      0.999191  0.999635  0.999675  1.000000   1.000000  0.065311
# adj_close  0.999191  0.999635  0.999675  1.000000   1.000000  0.065311
# volume     0.064499  0.068149  0.060838  0.065311   0.065311  1.000000

# %%
plt.figure(figsize=(14, 10))
heatmap = sns.heatmap(correlations.round(2), vmin=-1, vmax=1, annot=True, cmap='crest')
heatmap.set_title('Feature Correlations');

# %%
correlations = tsla_df.corr()
correlations
# Out:
#                        date_year  date_month  date_day  date_quarter  \
# date_year               1.000000   -0.077051 -0.000062     -0.076197
# date_month             -0.077051    1.000000 -0.000263      0.971246
# date_day               -0.000062   -0.000263  1.000000      0.004193
# date_quarter           -0.076197    0.971246  0.004193      1.000000
# date_is_month_start     0.002686    0.021413 -0.300960      0.017499
# date_is_month_end      -0.001041   -0.001642  0.313943     -0.001846
# returns_prc             0.010749   -0.002533  0.041305     -0.003012
# day_num                 0.996827    0.002272  0.006539      0.000886
# high_low_diff_mean      0.669507   -0.020104 -0.010076     -0.022681
# high_low_diff_std       0.566420    0.001237  0.016007      0.005182
# open_close_diff_mean    0.035862   -0.009694 -0.049727     -0.008348
# open_close_diff_std     0.586489   -0.029783 -0.006308     -0.029624
# volume_mean             0.435297   -0.084811 -0.031599     -0.078630
# volume_std              0.185448   -0.041774 -0.038525     -0.027394
# adj_close_mean          0.722088    0.012676 -0.002673      0.012298
# adj_close_std           0.581751   -0.020685 -0.010828     -0.023067
# high_low_diff          -0.007649   -0.010618 -0.012194     -0.010797
# lag_1_high_low_diff    -0.026657    0.003692 -0.028543      0.008682
# lag_2_high_low_diff    -0.029402    0.003570 -0.022936      0.008900
# lag_3_high_low_diff    -0.050960    0.021503  0.010182      0.023290
# open_close_diff         0.003900   -0.001114 -0.001722     -0.002121
# lag_1_open_close_diff   0.023070    0.001709  0.014202     -0.002710
# lag_2_open_close_diff   0.029953   -0.003207  0.031843     -0.008111
# lag_3_open_close_diff   0.033247   -0.000412  0.028961     -0.005866
# volume                  0.005550   -0.012795 -0.033691     -0.014871
# lag_1_volume           -0.030645    0.001919 -0.027901      0.007263
# lag_2_volume           -0.030645    0.001919 -0.027901      0.007263
# lag_3_volume           -0.030645    0.001919 -0.027901      0.007263
# adj_close              -0.001361   -0.010712  0.026471     -0.007716
# lag_1_adj_close        -0.030273    0.002297 -0.027012      0.007488
# lag_2_adj_close        -0.030064    0.003332 -0.032003      0.008197
# lag_3_adj_close        -0.053843   -0.019299 -0.027705     -0.012739
#
#                        date_is_month_start  date_is_month_end  returns_prc  \
# date_year                         0.002686          -0.001041     0.010749
# date_month                        0.021413          -0.001642    -0.002533
# date_day                         -0.300960           0.313943     0.041305
# date_quarter                      0.017499          -0.001846    -0.003012
# date_is_month_start               1.000000          -0.033415    -0.028376
# date_is_month_end                -0.033415           1.000000     0.014684
# returns_prc                      -0.028376           0.014684     1.000000
# day_num                           0.002393           0.000904     0.010829
# high_low_diff_mean                0.005546           0.000935    -0.033703
# high_low_diff_std                -0.000545           0.005326    -0.034020
# open_close_diff_mean             -0.023967          -0.032212    -0.330419
# open_close_diff_std               0.009399           0.010785    -0.023417
# volume_mean                      -0.018676          -0.010559     0.010051
# volume_std                       -0.002149          -0.019474     0.019992
# adj_close_mean                    0.011326           0.002138    -0.014453
# adj_close_std                     0.003457           0.000850    -0.017310
# high_low_diff                     0.021832          -0.026852    -0.008831
# lag_1_high_low_diff              -0.008604           0.005248    -0.114154
# lag_2_high_low_diff              -0.005695          -0.000863    -0.114370
# lag_3_high_low_diff               0.000685           0.038229    -0.079415
# open_close_diff                   0.042908           0.007210    -0.669108
# lag_1_open_close_diff            -0.008868           0.002878     0.309174
# lag_2_open_close_diff            -0.005814           0.000693     0.241724
# lag_3_open_close_diff             0.001231          -0.004291     0.165368
# volume                            0.014228          -0.011592    -0.000345
# lag_1_volume                     -0.003176          -0.003323    -0.118439
# lag_2_volume                     -0.003176          -0.003323    -0.118439
# lag_3_volume                     -0.003176          -0.003323    -0.118439
# adj_close                        -0.005113           0.006800     0.613986
# lag_1_adj_close                   0.001474          -0.006080    -0.215450
# lag_2_adj_close                  -0.005108          -0.002669    -0.154281
# lag_3_adj_close                  -0.007514          -0.002863    -0.119135
#
#                         day_num  high_low_diff_mean  high_low_diff_std  ...  \
# date_year              0.996827            0.669507           0.566420  ...
# date_month             0.002272           -0.020104           0.001237  ...
# date_day               0.006539           -0.010076           0.016007  ...
# date_quarter           0.000886           -0.022681           0.005182  ...
# date_is_month_start    0.002393            0.005546          -0.000545  ...
# date_is_month_end      0.000904            0.000935           0.005326  ...
# returns_prc            0.010829           -0.033703          -0.034020  ...
# day_num                1.000000            0.670015           0.568468  ...
# high_low_diff_mean     0.670015            1.000000           0.878044  ...
# high_low_diff_std      0.568468            0.878044           1.000000  ...
# open_close_diff_mean   0.034907            0.136266           0.112489  ...
# open_close_diff_std    0.585987            0.916532           0.869319  ...
# volume_mean            0.429417            0.168422           0.191848  ...
# volume_std             0.182276            0.024828           0.120917  ...
# adj_close_mean         0.725394            0.917567           0.778245  ...
# adj_close_std          0.581923            0.859234           0.800217  ...
# high_low_diff         -0.008641           -0.005361           0.019227  ...
# lag_1_high_low_diff   -0.026619           -0.001597          -0.006387  ...
# lag_2_high_low_diff   -0.029361           -0.010669          -0.013775  ...
# lag_3_high_low_diff   -0.049332           -0.047869          -0.048009  ...
# open_close_diff        0.003824           -0.003732          -0.001258  ...
# lag_1_open_close_diff  0.023370            0.007241           0.003220  ...
# lag_2_open_close_diff  0.030003            0.009914           0.010593  ...
# lag_3_open_close_diff  0.033510            0.010647           0.010244  ...
# volume                 0.004309            0.014416           0.034886  ...
# lag_1_volume          -0.030773           -0.008761          -0.008381  ...
# lag_2_volume          -0.030773           -0.008761          -0.008381  ...
# lag_3_volume          -0.030773           -0.008761          -0.008381  ...
# adj_close             -0.002100           -0.036275          -0.018068  ...
# lag_1_adj_close       -0.030363           -0.008277          -0.005312  ...
# lag_2_adj_close       -0.030097           -0.003194          -0.007232  ...
# lag_3_adj_close       -0.055708           -0.007293          -0.012804  ...
#
#                        lag_2_open_close_diff  lag_3_open_close_diff    volume  \
# date_year                           0.029953               0.033247  0.005550
# date_month                         -0.003207              -0.000412 -0.012795
# date_day                            0.031843               0.028961 -0.033691
# date_quarter                       -0.008111              -0.005866 -0.014871
# date_is_month_start                -0.005814               0.001231  0.014228
# date_is_month_end                   0.000693              -0.004291 -0.011592
# returns_prc                         0.241724               0.165368 -0.000345
# day_num                             0.030003               0.033510  0.004309
# high_low_diff_mean                  0.009914               0.010647  0.014416
# high_low_diff_std                   0.010593               0.010244  0.034886
# open_close_diff_mean               -0.000709              -0.047776  0.026558
# open_close_diff_std                 0.006798               0.012141  0.015162
# volume_mean                         0.004674               0.002970 -0.029195
# volume_std                          0.017648               0.013101  0.045799
# adj_close_mean                      0.008786               0.013519  0.010747
# adj_close_std                       0.017802               0.011419  0.113821
# high_low_diff                       0.000711               0.001236  0.622488
# lag_1_high_low_diff                -0.822394              -0.850928 -0.109559
# lag_2_high_low_diff                -0.906212              -0.932475 -0.096654
# lag_3_high_low_diff                -0.638135              -0.669137 -0.060082
# open_close_diff                    -0.178006               0.000567 -0.029233
# lag_1_open_close_diff               0.572159               0.711218 -0.017770
# lag_2_open_close_diff               1.000000               0.901098  0.016584
# lag_3_open_close_diff               0.901098               1.000000  0.004346
# volume                              0.016584               0.004346  1.000000
# lag_1_volume                       -0.931434              -0.961672  0.000958
# lag_2_volume                       -0.931434              -0.961672  0.000958
# lag_3_volume                       -0.931434              -0.961672  0.000958
# adj_close                           0.129925               0.058881  0.012516
# lag_1_adj_close                    -0.911973              -0.940459  0.000378
# lag_2_adj_close                    -0.940380              -0.959461 -0.000579
# lag_3_adj_close                    -0.607171              -0.724923  0.046706
#
#                        lag_1_volume  lag_2_volume  lag_3_volume  adj_close  \
# date_year                 -0.030645     -0.030645     -0.030645  -0.001361
# date_month                 0.001919      0.001919      0.001919  -0.010712
# date_day                  -0.027901     -0.027901     -0.027901   0.026471
# date_quarter               0.007263      0.007263      0.007263  -0.007716
# date_is_month_start       -0.003176     -0.003176     -0.003176  -0.005113
# date_is_month_end         -0.003323     -0.003323     -0.003323   0.006800
# returns_prc               -0.118439     -0.118439     -0.118439   0.613986
# day_num                   -0.030773     -0.030773     -0.030773  -0.002100
# high_low_diff_mean        -0.008761     -0.008761     -0.008761  -0.036275
# high_low_diff_std         -0.008381     -0.008381     -0.008381  -0.018068
# open_close_diff_mean       0.001775      0.001775      0.001775  -0.296895
# open_close_diff_std       -0.008504     -0.008504     -0.008504  -0.024098
# volume_mean               -0.004024     -0.004024     -0.004024   0.028740
# volume_std                -0.014595     -0.014595     -0.014595   0.026816
# adj_close_mean            -0.010808     -0.010808     -0.010808  -0.018586
# adj_close_std             -0.008471     -0.008471     -0.008471  -0.017003
# high_low_diff              0.000636      0.000636      0.000636  -0.041338
# lag_1_high_low_diff        0.882463      0.882463      0.882463  -0.006039
# lag_2_high_low_diff        0.967977      0.967977      0.967977   0.010663
# lag_3_high_low_diff        0.690611      0.690611      0.690611   0.013448
# open_close_diff            0.000103      0.000103      0.000103  -0.430726
# lag_1_open_close_diff     -0.741336     -0.741336     -0.741336   0.044232
# lag_2_open_close_diff     -0.931434     -0.931434     -0.931434   0.129925
# lag_3_open_close_diff     -0.961672     -0.961672     -0.961672   0.058881
# volume                     0.000958      0.000958      0.000958   0.012516
# lag_1_volume               1.000000      1.000000      1.000000  -0.001341
# lag_2_volume               1.000000      1.000000      1.000000  -0.001341
# lag_3_volume               1.000000      1.000000      1.000000  -0.001341
# adj_close                 -0.001341     -0.001341     -0.001341   1.000000
# lag_1_adj_close            0.978617      0.978617      0.978617  -0.082204
# lag_2_adj_close            0.987580      0.987580      0.987580  -0.109611
# lag_3_adj_close            0.730637      0.730637      0.730637  -0.094957
#
#                        lag_1_adj_close  lag_2_adj_close  lag_3_adj_close
# date_year                    -0.030273        -0.030064        -0.053843
# date_month                    0.002297         0.003332        -0.019299
# date_day                     -0.027012        -0.032003        -0.027705
# date_quarter                  0.007488         0.008197        -0.012739
# date_is_month_start           0.001474        -0.005108        -0.007514
# date_is_month_end            -0.006080        -0.002669        -0.002863
# returns_prc                  -0.215450        -0.154281        -0.119135
# day_num                      -0.030363        -0.030097        -0.055708
# high_low_diff_mean           -0.008277        -0.003194        -0.007293
# high_low_diff_std            -0.005312        -0.007232        -0.012804
# open_close_diff_mean          0.007895         0.044627         0.129957
# open_close_diff_std          -0.007992        -0.004870        -0.010989
# volume_mean                  -0.001579        -0.009904        -0.023825
# volume_std                   -0.011475        -0.020331        -0.025078
# adj_close_mean               -0.009264        -0.008613        -0.029638
# adj_close_std                -0.007470        -0.006238         0.013393
# high_low_diff                 0.005450         0.004117         0.034761
# lag_1_high_low_diff           0.863068         0.872627         0.646387
# lag_2_high_low_diff           0.946526         0.954826         0.698273
# lag_3_high_low_diff           0.676354         0.679852         0.507383
# open_close_diff               0.132272        -0.011743        -0.121615
# lag_1_open_close_diff        -0.813776        -0.685869        -0.602982
# lag_2_open_close_diff        -0.911973        -0.940380        -0.607171
# lag_3_open_close_diff        -0.940459        -0.959461        -0.724923
# volume                        0.000378        -0.000579         0.046706
# lag_1_volume                  0.978617         0.987580         0.730637
# lag_2_volume                  0.978617         0.987580         0.730637
# lag_3_volume                  0.978617         0.987580         0.730637
# adj_close                    -0.082204        -0.109611        -0.094957
# lag_1_adj_close               1.000000         0.953725         0.709775
# lag_2_adj_close               0.953725         1.000000         0.739499
# lag_3_adj_close               0.709775         0.739499         1.000000
#
# [32 rows x 32 columns]

# %%
plt.figure(figsize=(14, 10))
heatmap = sns.heatmap(correlations.round(2), vmin=-1, vmax=1, cmap='RdYlBu')
heatmap.set_title('Feature Correlations - Preprocessed Tesla Dataset');

# %% [markdown]
# #### Esports Gaming Group

# %%
correlations = raw_gmbl_df.corr()
correlations
# Out:
#                open      high       low     close  adj_close    volume
# open       1.000000  0.995568  0.992051  0.992870   0.992870 -0.090199
# high       0.995568  1.000000  0.988765  0.994720   0.994720 -0.089693
# low        0.992051  0.988765  1.000000  0.995051   0.995051 -0.089441
# close      0.992870  0.994720  0.995051  1.000000   1.000000 -0.090161
# adj_close  0.992870  0.994720  0.995051  1.000000   1.000000 -0.090161
# volume    -0.090199 -0.089693 -0.089441 -0.090161  -0.090161  1.000000

# %%
plt.figure(figsize=(12, 8))
heatmap = sns.heatmap(correlations.round(2), vmin=-1, vmax=1, annot=True)
heatmap.set_title('Feature Correlations - Esports Gaming Group Dataset');

# %%
correlations = gmbl_df.corr()
correlations
# Out:
#                        date_year  date_month  date_day  date_quarter  \
# date_year               1.000000   -0.171478 -0.010353     -0.167995
# date_month             -0.171478    1.000000  0.001763      0.971877
# date_day               -0.010353    0.001763  1.000000      0.007758
# date_quarter           -0.167995    0.971877  0.007758      1.000000
# date_is_month_start     0.004170    0.021307 -0.304581      0.016868
# date_is_month_end      -0.001892   -0.000173  0.312915      0.003124
# returns_prc             0.002195   -0.062688  0.020269     -0.068193
# day_num                 0.983465    0.009136  0.004927      0.007649
# high_low_diff_mean     -0.481227   -0.039089 -0.050227     -0.045680
# high_low_diff_std      -0.578551   -0.021173 -0.055586     -0.030121
# open_close_diff_mean   -0.120605    0.123196 -0.071539      0.131100
# open_close_diff_std    -0.519915   -0.038986 -0.070313     -0.041957
# volume_mean             0.208499   -0.095578  0.064283     -0.083634
# volume_std              0.178351   -0.091865  0.066651     -0.079837
# adj_close_mean         -0.677737    0.058499  0.005748      0.060332
# adj_close_std          -0.481665   -0.001534 -0.064045     -0.004968
# high_low_diff          -0.022732    0.020794  0.024847      0.019717
# lag_1_high_low_diff    -0.046514    0.002087  0.028037      0.010080
# lag_2_high_low_diff    -0.046475    0.002078  0.028205      0.010076
# lag_3_high_low_diff    -0.092309   -0.008385  0.018467     -0.012835
# open_close_diff        -0.015195   -0.001256  0.010579     -0.004527
# lag_1_open_close_diff   0.046510   -0.002139 -0.028180     -0.010134
# lag_2_open_close_diff  -0.046379    0.002121  0.028085      0.010110
# lag_3_open_close_diff   0.063203    0.009320 -0.001521      0.015320
# volume                 -0.038529    0.008431 -0.001214      0.015160
# lag_1_volume           -0.046501    0.002110  0.028163      0.010101
# lag_2_volume           -0.046501    0.002109  0.028166      0.010100
# lag_3_volume           -0.049952   -0.030898  0.022511     -0.029146
# adj_close              -0.013452   -0.018527 -0.011014     -0.020290
# lag_1_adj_close         0.046222   -0.001704 -0.027770     -0.009690
# lag_2_adj_close         0.046598   -0.002082 -0.028180     -0.010072
# lag_3_adj_close        -0.049517   -0.008726 -0.013462     -0.007857
#
#                        date_is_month_start  date_is_month_end  returns_prc  \
# date_year                         0.004170          -0.001892     0.002195
# date_month                        0.021307          -0.000173    -0.062688
# date_day                         -0.304581           0.312915     0.020269
# date_quarter                      0.016868           0.003124    -0.068193
# date_is_month_start               1.000000          -0.033823     0.014175
# date_is_month_end                -0.033823           1.000000     0.033225
# returns_prc                       0.014175           0.033225     1.000000
# day_num                           0.003513           0.002792    -0.009012
# high_low_diff_mean                0.029603           0.002778    -0.057277
# high_low_diff_std                 0.045889           0.016550    -0.038641
# open_close_diff_mean              0.007943           0.029457    -0.452375
# open_close_diff_std               0.044293           0.013294    -0.070698
# volume_mean                      -0.007249           0.009168    -0.038872
# volume_std                       -0.006048           0.014554    -0.007278
# adj_close_mean                    0.010053          -0.000425    -0.000824
# adj_close_std                     0.018891           0.004809    -0.081120
# high_low_diff                     0.007104           0.050961    -0.038364
# lag_1_high_low_diff              -0.004720          -0.005151    -0.000137
# lag_2_high_low_diff              -0.004946          -0.005059     0.000012
# lag_3_high_low_diff              -0.013915          -0.014601     0.007369
# open_close_diff                  -0.013548          -0.013008    -0.618315
# lag_1_open_close_diff             0.004844           0.005066     0.002748
# lag_2_open_close_diff            -0.004798          -0.004988     0.000838
# lag_3_open_close_diff             0.009556           0.001855    -0.002345
# volume                           -0.027052           0.075250     0.021418
# lag_1_volume                     -0.004839          -0.005026    -0.000102
# lag_2_volume                     -0.004852          -0.005022    -0.000097
# lag_3_volume                     -0.008141          -0.008425     0.002509
# adj_close                         0.023718           0.005671     0.469963
# lag_1_adj_close                   0.004225           0.004590    -0.011810
# lag_2_adj_close                   0.004825           0.005038    -0.000520
# lag_3_adj_close                  -0.013218          -0.003211     0.021564
#
#                         day_num  high_low_diff_mean  high_low_diff_std  ...  \
# date_year              0.983465           -0.481227          -0.578551  ...
# date_month             0.009136           -0.039089          -0.021173  ...
# date_day               0.004927           -0.050227          -0.055586  ...
# date_quarter           0.007649           -0.045680          -0.030121  ...
# date_is_month_start    0.003513            0.029603           0.045889  ...
# date_is_month_end      0.002792            0.002778           0.016550  ...
# returns_prc           -0.009012           -0.057277          -0.038641  ...
# day_num                1.000000           -0.496407          -0.591791  ...
# high_low_diff_mean    -0.496407            1.000000           0.781163  ...
# high_low_diff_std     -0.591791            0.781163           1.000000  ...
# open_close_diff_mean  -0.100835            0.232339           0.232811  ...
# open_close_diff_std   -0.535889            0.809192           0.750527  ...
# volume_mean            0.195213           -0.074002          -0.072196  ...
# volume_std             0.165314           -0.067219          -0.057636  ...
# adj_close_mean        -0.676982            0.535963           0.582685  ...
# adj_close_std         -0.490059            0.676824           0.691047  ...
# high_low_diff         -0.018982           -0.016135           0.005203  ...
# lag_1_high_low_diff   -0.046458            0.007739          -0.019518  ...
# lag_2_high_low_diff   -0.046418            0.007690          -0.019563  ...
# lag_3_high_low_diff   -0.094845           -0.067446          -0.056751  ...
# open_close_diff       -0.015529            0.023504           0.006123  ...
# lag_1_open_close_diff  0.046442           -0.007713           0.019532  ...
# lag_2_open_close_diff -0.046314            0.007577          -0.019576  ...
# lag_3_open_close_diff  0.065819            0.039432           0.021756  ...
# volume                -0.037660           -0.007175           0.015122  ...
# lag_1_volume          -0.046439            0.007678          -0.019541  ...
# lag_2_volume          -0.046439            0.007676          -0.019544  ...
# lag_3_volume          -0.056006           -0.017789          -0.032799  ...
# adj_close             -0.017277            0.006993           0.007949  ...
# lag_1_adj_close        0.046236           -0.006861           0.019674  ...
# lag_2_adj_close        0.046542           -0.007779           0.019498  ...
# lag_3_adj_close       -0.052032            0.018067           0.050980  ...
#
#                        lag_2_open_close_diff  lag_3_open_close_diff    volume  \
# date_year                          -0.046379               0.063203 -0.038529
# date_month                          0.002121               0.009320  0.008431
# date_day                            0.028085              -0.001521 -0.001214
# date_quarter                        0.010110               0.015320  0.015160
# date_is_month_start                -0.004798               0.009556 -0.027052
# date_is_month_end                  -0.004988               0.001855  0.075250
# returns_prc                         0.000838              -0.002345  0.021418
# day_num                            -0.046314               0.065819 -0.037660
# high_low_diff_mean                  0.007577               0.039432 -0.007175
# high_low_diff_std                  -0.019576               0.021756  0.015122
# open_close_diff_mean                0.019846              -0.000704  0.021524
# open_close_diff_std                -0.021307               0.041277  0.001949
# volume_mean                        -0.003679               0.007395 -0.007088
# volume_std                         -0.002927               0.005827  0.013103
# adj_close_mean                      0.121421              -0.094906  0.020980
# adj_close_std                      -0.019265              -0.003653  0.098045
# high_low_diff                       0.000258              -0.010863  0.539702
# lag_1_high_low_diff                 0.999986              -0.078951  0.000177
# lag_2_high_low_diff                 0.999990              -0.078950  0.000604
# lag_3_high_low_diff                 0.122277              -0.637537 -0.010476
# open_close_diff                    -0.000818              -0.001685 -0.054731
# lag_1_open_close_diff              -0.999972               0.078987 -0.001130
# lag_2_open_close_diff               1.000000              -0.078988  0.001388
# lag_3_open_close_diff              -0.078988               1.000000 -0.006133
# volume                              0.001388              -0.006133  1.000000
# lag_1_volume                        0.999994              -0.078960  0.001082
# lag_2_volume                        0.999994              -0.078971  0.001186
# lag_3_volume                        0.710981              -0.054878  0.002025
# adj_close                           0.003994              -0.034417  0.129954
# lag_1_adj_close                    -0.999372               0.079489 -0.004063
# lag_2_adj_close                    -0.999991               0.079032 -0.001401
# lag_3_adj_close                     0.114459               0.028468 -0.014794
#
#                        lag_1_volume  lag_2_volume  lag_3_volume  adj_close  \
# date_year                 -0.046501     -0.046501     -0.049952  -0.013452
# date_month                 0.002110      0.002109     -0.030898  -0.018527
# date_day                   0.028163      0.028166      0.022511  -0.011014
# date_quarter               0.010101      0.010100     -0.029146  -0.020290
# date_is_month_start       -0.004839     -0.004852     -0.008141   0.023718
# date_is_month_end         -0.005026     -0.005022     -0.008425   0.005671
# returns_prc               -0.000102     -0.000097      0.002509   0.469963
# day_num                   -0.046439     -0.046439     -0.056006  -0.017277
# high_low_diff_mean         0.007678      0.007676     -0.017789   0.006993
# high_low_diff_std         -0.019541     -0.019544     -0.032799   0.007949
# open_close_diff_mean       0.019853      0.019858      0.011776  -0.188962
# open_close_diff_std       -0.021279     -0.021282     -0.035711   0.013468
# volume_mean               -0.003707     -0.003710     -0.006229  -0.002613
# volume_std                -0.002991     -0.002991     -0.005023   0.008311
# adj_close_mean             0.121683      0.121683      0.088463  -0.011204
# adj_close_std             -0.019162     -0.019175     -0.032160   0.019464
# high_low_diff              0.000181      0.000237      0.000415   0.081424
# lag_1_high_low_diff        0.999994      0.999993      0.710982   0.002836
# lag_2_high_low_diff        0.999997      0.999997      0.710982   0.002769
# lag_3_high_low_diff        0.122273      0.122282      0.397533   0.023592
# open_close_diff            0.000692      0.000683      0.001129  -0.429921
# lag_1_open_close_diff     -0.999964     -0.999964     -0.710962  -0.002121
# lag_2_open_close_diff      0.999994      0.999994      0.710981   0.003994
# lag_3_open_close_diff     -0.078960     -0.078971     -0.054878  -0.034417
# volume                     0.001082      0.001186      0.002025   0.129954
# lag_1_volume               1.000000      1.000000      0.710986   0.002907
# lag_2_volume               1.000000      1.000000      0.710986   0.002911
# lag_3_volume               0.710986      0.710986      1.000000   0.004893
# adj_close                  0.002907      0.002911      0.004893   1.000000
# lag_1_adj_close           -0.999385     -0.999386     -0.710549  -0.017123
# lag_2_adj_close           -0.999994     -0.999994     -0.710990  -0.005096
# lag_3_adj_close            0.114197      0.114205      0.080066   0.002868
#
#                        lag_1_adj_close  lag_2_adj_close  lag_3_adj_close
# date_year                     0.046222         0.046598        -0.049517
# date_month                   -0.001704        -0.002082        -0.008726
# date_day                     -0.027770        -0.028180        -0.013462
# date_quarter                 -0.009690        -0.010072        -0.007857
# date_is_month_start           0.004225         0.004825        -0.013218
# date_is_month_end             0.004590         0.005038        -0.003211
# returns_prc                  -0.011810        -0.000520         0.021564
# day_num                       0.046236         0.046542        -0.052032
# high_low_diff_mean           -0.006861        -0.007779         0.018067
# high_low_diff_std             0.019674         0.019498         0.050980
# open_close_diff_mean         -0.019704        -0.019249         0.044772
# open_close_diff_std           0.021950         0.021192         0.013952
# volume_mean                   0.003886         0.003706        -0.006140
# volume_std                    0.002778         0.002982        -0.004929
# adj_close_mean               -0.120833        -0.121788         0.040508
# adj_close_std                 0.019172         0.019114        -0.032566
# high_low_diff                 0.001207        -0.000652        -0.027451
# lag_1_high_low_diff          -0.999383        -0.999987         0.114159
# lag_2_high_low_diff          -0.999383        -0.999991         0.114278
# lag_3_high_low_diff          -0.122604        -0.122326        -0.175570
# open_close_diff               0.017535        -0.000685        -0.046190
# lag_1_open_close_diff         0.999175         0.999970        -0.114415
# lag_2_open_close_diff        -0.999372        -0.999991         0.114459
# lag_3_open_close_diff         0.079489         0.079032         0.028468
# volume                       -0.004063        -0.001401        -0.014794
# lag_1_volume                 -0.999385        -0.999994         0.114197
# lag_2_volume                 -0.999386        -0.999994         0.114205
# lag_3_volume                 -0.710549        -0.710990         0.080066
# adj_close                    -0.017123        -0.005096         0.002868
# lag_1_adj_close               1.000000         0.999329        -0.114190
# lag_2_adj_close               0.999329         1.000000        -0.114195
# lag_3_adj_close              -0.114190        -0.114195         1.000000
#
# [32 rows x 32 columns]

# %%
plt.figure(figsize=(14, 10))
heatmap = sns.heatmap(correlations.round(2), vmin=-1, vmax=1, cmap='RdYlBu')
heatmap.set_title('Feature Correlations - Preprocessed Esports Gaming Group Dataset');

# %% [markdown]
# ### Split dates for raw data

# %%
raw_aapl_df = split_date(raw_aapl_df, target_col='date')
raw_tsla_df = split_date(raw_tsla_df, target_col='date')
raw_gmbl_df = split_date(raw_gmbl_df, target_col='date')

# %% [markdown]
# ### Data subset for plot

# %%
# NOTE: Creating a mask to create subset of data to produce uncluttered plots
year_since = 2012
mask = 'date_year > @year_since'

# %% [markdown]
# ### Volume over time

# %% [markdown]
# #### Apple

# %%
plt.figure(figsize=(14, 10))
plot = sns.lineplot(x=raw_aapl_df.date, y=raw_aapl_df.volume)
plot.set_title('Apple - Volume over time');

# %% [markdown]
# #### Tesla

# %%
plt.figure(figsize=(14, 10))
plot = sns.lineplot(x=raw_tsla_df.date, y=raw_tsla_df.volume, color='r')
plot.set_title('Tesla - Volume over time');

# %% [markdown]
# #### Esports Gaming Group

# %%
plt.figure(figsize=(14, 10))
plot = sns.lineplot(x=raw_gmbl_df.date, y=raw_gmbl_df.volume, color='g')
plot.set_title('Esports Gaming Group - Volume over time');

# %% [markdown]
# ### Price over time

# %% [markdown]
# #### Apple

# %%
plt.figure(figsize=(16, 9))
plot = sns.lineplot(
    x=raw_aapl_df.query(mask).date,
    y=raw_aapl_df.query(mask).adj_close,
    palette='bright'
)
plot.set_title('Apple - Price over time');

# %% [markdown]
# #### Tesla

# %%
plt.figure(figsize=(16, 9))
plot = sns.lineplot(
    x=raw_tsla_df.query(mask).date,
    y=raw_tsla_df.query(mask).adj_close,
    palette='bright',
    color='r'
)
plot.set_title('Tesla - Price over time');

# %% [markdown]
# #### Esports Gaming Group

# %%
plt.figure(figsize=(16, 9))
plot = sns.lineplot(
    x=raw_gmbl_df.query(mask).date,
    y=raw_gmbl_df.query(mask).adj_close,
    palette='bright',
    color='g'
)
plot.set_title('Esports Gaming Group - Price over time');

# %% [markdown]
# ### Price over time

# %% [markdown]
# #### Apple

# %%
fig, axes = plt.subplots(nrows=5, ncols=1, figsize=(12, 10))
sns.lineplot(x=raw_aapl_df.query(mask).date,
             y=raw_aapl_df.query(mask).open,
             ax=axes[0],
             color='red')
sns.lineplot(x=raw_aapl_df.query(mask).date,
             y=raw_aapl_df.query(mask).high,
             ax=axes[1],
             color='yellow')
sns.lineplot(x=raw_aapl_df.query(mask).date,
             y=raw_aapl_df.query(mask).low,
             ax=axes[2],
             color='blue')
sns.lineplot(x=raw_aapl_df.query(mask).date,
             y=raw_aapl_df.query(mask).close,
             ax=axes[3],
             color='green')
sns.lineplot(x=raw_aapl_df.query(mask).date,
             y=raw_aapl_df.query(mask).adj_close,
             ax=axes[4],
             color='black')

axes[0].set_title("Open")
axes[1].set_title("High")
axes[2].set_title("Low")
axes[3].set_title("Close")
axes[4].set_title("Adjusted Close")
fig.tight_layout(pad=3)

plt.suptitle(f'Apple Stock (since {year_since})')

plt.show()

# %% [markdown]
# #### Tesla

# %%
fig, axes = plt.subplots(nrows=5, ncols=1, figsize=(12, 10))
sns.lineplot(x=raw_tsla_df.query(mask).date,
             y=raw_tsla_df.query(mask).open,
             ax=axes[0],
             color='red')
sns.lineplot(x=raw_tsla_df.query(mask).date,
             y=raw_tsla_df.query(mask).high,
             ax=axes[1],
             color='yellow')
sns.lineplot(x=raw_tsla_df.query(mask).date,
             y=raw_tsla_df.query(mask).low,
             ax=axes[2],
             color='blue')
sns.lineplot(x=raw_tsla_df.query(mask).date,
             y=raw_tsla_df.query(mask).close,
             ax=axes[3],
             color='green')
sns.lineplot(x=raw_tsla_df.query(mask).date,
             y=raw_tsla_df.query(mask).adj_close,
             ax=axes[4],
             color='black')

axes[0].set_title("Open")
axes[1].set_title("High")
axes[2].set_title("Low")
axes[3].set_title("Close")
axes[4].set_title("Adjusted Close")
fig.tight_layout(pad=3)

plt.suptitle(f'Tesla Stock (since {year_since})')

plt.show()

# %% [markdown]
# #### Esports Gaming Group

# %%
fig, axes = plt.subplots(nrows=5, ncols=1, figsize=(12, 10))
sns.lineplot(x=raw_gmbl_df.query(mask).date,
             y=raw_gmbl_df.query(mask).open,
             ax=axes[0],
             color='red')
sns.lineplot(x=raw_gmbl_df.query(mask).date,
             y=raw_gmbl_df.query(mask).high,
             ax=axes[1],
             color='yellow')
sns.lineplot(x=raw_gmbl_df.query(mask).date,
             y=raw_gmbl_df.query(mask).low,
             ax=axes[2],
             color='blue')
sns.lineplot(x=raw_gmbl_df.query(mask).date,
             y=raw_gmbl_df.query(mask).close,
             ax=axes[3],
             color='green')
sns.lineplot(x=raw_gmbl_df.query(mask).date,
             y=raw_gmbl_df.query(mask).adj_close,
             ax=axes[4],
             color='black')

axes[0].set_title("Open")
axes[1].set_title("High")
axes[2].set_title("Low")
axes[3].set_title("Close")
axes[4].set_title("Adjusted Close")
fig.tight_layout(pad=3)

plt.suptitle(f'Esports Gaming Group Stock (since {year_since})')

plt.show()

# %% [markdown]
# ### Seasonal Trends

# %% [markdown]
# #### Apple

# %%
# Last n days visualized
n = 1000
result_data = seasonal_decompose(
    raw_aapl_df.adj_close.tail(n),
    model='additive',
    period=30
)

fig = go.Figure()
fig = result_data.plot()
fig.set_size_inches(20, 19)

# %% [markdown]
# #### Tesla

# %%
# Last n days visualized
n = 1000
result_data = seasonal_decompose(
    raw_tsla_df.adj_close.tail(n),
    model='additive',
    period=30
)

fig = go.Figure()
fig = result_data.plot()
fig.set_size_inches(20, 19)

# %% [markdown]
# #### Esports Gaming Group

# %%
# Last n days visualized
n = 1000
result_data = seasonal_decompose(
    raw_gmbl_df.adj_close.tail(n),
    model='additive',
    period=30
)

fig = go.Figure()
fig = result_data.plot()
fig.set_size_inches(20, 19)
